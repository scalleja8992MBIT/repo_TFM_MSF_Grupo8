# %% [markdown]
# # Notebook TFM
# <div style="background-color:#F2EDED;">
# <br/>
# <div>
# <img src="https://uploads-ssl.webflow.com/614b1fe22fa8b90ef41aeffe/6265cb48f9496b1cefc9ab75_logotipo-mbit-39.png" width="200px" align="left" CLASS="TextWrap" style="background-color:#2a3f3f; margin-left: 10px;">
# <img src="https://branding-guidelines.msf.es/esp/imgs/logo/Logo-01.jpg" width="100px" align="right" CLASS="TextWrap" style="background-color:#2a3f3f;">
# </div>
# <br/>
# <br/>
# <br/>
# <div>
# <h1><font color="#2a3f3f" size=4 style="margin-left: 10px;">MODELO DE PROBABILIDAD A TESTAR EN MÉDICOS SIN FRONTERAS</font></h1>
# </div>
# <br/>
# <div style="text-align: right; margin-right: 10px; margin-bottom: 10px;">
# <font color="#2a3f3f" size=3>Elio López Salamanca </font><br>
# <font color="#2a3f3f" size=3>Sergio Israel Calleja Chimeno</font><br>
# </div>
# </div>

# %% [markdown]
# En este proyecto vamos a generar un caso de uso que ayude a MSF a detectar socios potenciales que puedan
# dejar el testamento a favor de MSF.
#
# En este notebook vamos a hacer el preprocesamiento necesario para poder entrenar y evaluar un modelo
# que prediga si el socio potencialmente puede dejar dicho testamento a favor
#
# Este notebook consiste en los siguientes pasos
#
# 1. **Lectura de datos**: lectura de la BBDD carga en Athena
# 2. **Exploratorio y limpieza de datos**: hacemos un exploratorio y limpieza de datos
# 3. **Analisis en profundidad de datos**: analizamos en profundidad la información
# 4. **Generación dataset entrenamiento**: dejamos un dataset listo para entrenar/evaluar nuestro modelo

# %% [markdown]
# ## Imports e instalables necesarios

# %%
# %%capture --no-display
import sys
# !{sys.executable} -m pip install awswrangler;

# %%
import awswrangler as wr
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from types import NoneType
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Leemos los datos de Athena
# - Para ello nos apoyamos en la libreria awswrangler, que nos permite leer los datos de Athena, de una manera eficiente en memoria
# - Agrupamos todos los campos categóricos en listas, para facilitar el traslado a columnas, de una manera más eficiente que el uso de get_dummies

# %%
# %%time

path = 's3://enriched-msf-mbit/ContactsOpportunitiesAgg/'

df_model_athena = wr.athena.read_sql_query('''select 
array_agg(distinct opp_rating) as opp_rating,
array_agg(distinct opp_stagename) as opp_stagename,
array_agg(distinct opp_program) as opp_program,
array_agg(distinct opp_typefundraisingcontribution) as opp_typefundraisingcontribution,
cnt_id, 
max(cnt_ltvscore ) as cnt_ltvscore ,
array_agg(distinct cnt_program) as cnt_program ,
max(cnt_programaherencias ) as cnt_programaherencias ,
max(cnt_programais) as cnt_programais,
max(cnt_legacyconfidentiality ) as cnt_legacyconfidentiality ,
array_agg(distinct cnt_membertype ) as cnt_membertype ,
array_agg(distinct cmp_campaigndonationreporting ) as cmp_campaigndonationreporting ,
array_agg(distinct cmp_campaignentryreporting) as cmp_campaignentryreporting,
max(cmp_isemergency ) as cmp_isemergency ,
array_agg(distinct cmp_isonline ) as cmp_isonline ,
array_agg(distinct cmp_objective ) as cmp_objective ,
array_agg(distinct cmp_objectivepublic ) as cmp_objectivepublic ,
array_agg(distinct cmp_segment ) as cmp_segment ,
array_agg(distinct cmp_status) as cmp_status,
max(rcd_isdeleted ) as rcd_isdeleted ,
max(rcd_annualizedquota ) as rcd_annualizedquota ,
max(rcd_amount ) as rcd_amount ,
max(rcd_paidamount) as rcd_paidamount,
max(rcd_totalpaidinstallments) as rcd_totalpaidinstallments,
array_agg(distinct rcd_installmentperiod) as rcd_installmentperiod,
array_agg(distinct opp_type) as opp_type
FROM msfdb_enrich.enrich_contactsopportunitiesagg
group by cnt_id''', database="msfdb_enrich")

df_model_athena.head(8)
# Out:
# CPU times: user 4.49 s, sys: 978 ms, total: 5.46 s
# Wall time: 14.9 s
#      opp_rating               opp_stagename  \
# 0  [Caliente, ]  [Cobrada, Puesta al cobro]
# 1  [Caliente, ]  [Cobrada, Puesta al cobro]
# 2    [Caliente]  [Cobrada, Puesta al cobro]
# 3            []         [Cobrada, Impagada]
# 4  [, Caliente]  [Cobrada, Puesta al cobro]
# 5  [, Caliente]  [Cobrada, Puesta al cobro]
# 6  [Caliente, ]  [Cobrada, Puesta al cobro]
# 7  [Caliente, ]  [Cobrada, Puesta al cobro]
#
#                                          opp_program  \
# 0                        [, Cultivacion socios MASS]
# 1                        [Cultivacion socios MASS, ]
# 2  [Retencion 1r ano MASS, Cultivacion socios MAS...
# 3                                                 []
# 4                        [, Cultivacion socios MASS]
# 5                        [, Cultivacion socios MASS]
# 6  [Retencion 1r ano MASS, Cultivacion socios MAS...
# 7                        [, Cultivacion socios MASS]
#
#   opp_typefundraisingcontribution              cnt_id  cnt_ltvscore  \
# 0                             [S]  0033Y00002uphFXQAY           8.0
# 1                             [S]  0033Y00002uNmm0QAC           7.0
# 2                             [S]  0033Y00003S4BQWQA3           2.0
# 3                             [S]  0033Y00002upLF4QAM           2.0
# 4                             [S]  0033Y00002up3VFQAY           7.0
# 5                             [S]  0033Y00002upsjcQAA           8.0
# 6                             [S]  0033Y00002uq3jlQAA           6.0
# 7                             [S]  0033Y00002unbTCQAY           7.0
#
#                  cnt_program  cnt_programaherencias  cnt_programais  \
# 0  [Cultivacion socios MASS]                  False           False
# 1  [Cultivacion socios MASS]                  False           False
# 2  [Cultivacion socios MASS]                  False           False
# 3  [Reactivacion bajas MASS]                  False           False
# 4  [Cultivacion socios MASS]                  False           False
# 5  [Cultivacion socios MASS]                  False           False
# 6  [Cultivacion socios MASS]                  False           False
# 7  [Cultivacion socios MASS]                  False            True
#
#    cnt_legacyconfidentiality  ... cmp_objectivepublic        cmp_segment  \
# 0                      False  ...                  []      [Mass donors]
# 1                      False  ...                  []  [Frio individuos]
# 2                      False  ...                  []      [Mass donors]
# 3                      False  ...                  []  [Frio individuos]
# 4                      False  ...                  []  [Frio individuos]
# 5                      False  ...                  []  [Frio individuos]
# 6                      False  ...                  []            [Leads]
# 7                      False  ...                  []  [Frio individuos]
#
#     cmp_status  rcd_isdeleted rcd_annualizedquota rcd_amount rcd_paidamount  \
# 0  [Completed]          False               300.0      300.0         1200.0
# 1  [Completed]          False               120.0       10.0          670.0
# 2    [Created]          False                72.0        6.0           78.0
# 3  [Completed]          False                30.0       30.0           60.0
# 4  [Completed]          False               180.0       15.0         1005.0
# 5  [Completed]          False               360.0       30.0         1722.0
# 6  [Completed]          False               204.0       17.0          714.0
# 7  [Completed]          False               180.0       15.0         1005.0
#
#   rcd_totalpaidinstallments rcd_installmentperiod              opp_type
# 0                       5.0              [Yearly]  [Recurrent Donation]
# 1                      67.0             [Monthly]  [Recurrent Donation]
# 2                      13.0             [Monthly]  [Recurrent Donation]
# 3                       2.0              [Yearly]  [Recurrent Donation]
# 4                      67.0             [Monthly]  [Recurrent Donation]
# 5                      67.0             [Monthly]  [Recurrent Donation]
# 6                      42.0             [Monthly]  [Recurrent Donation]
# 7                      67.0             [Monthly]  [Recurrent Donation]
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Exploratorio de datos
# - Vemos los tipos de columna
# - Vemos volumetrias

# %%
df_model_athena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687224 entries, 0 to 687223
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   opp_rating                       687224 non-null  object
#  1   opp_stagename                    687224 non-null  object
#  2   opp_program                      687224 non-null  object
#  3   opp_typefundraisingcontribution  687224 non-null  object
#  4   cnt_id                           687224 non-null  string
#  5   cnt_ltvscore                     687224 non-null  float64
#  6   cnt_program                      687224 non-null  object
#  7   cnt_programaherencias            687224 non-null  boolean
#  8   cnt_programais                   687224 non-null  boolean
#  9   cnt_legacyconfidentiality        687224 non-null  boolean
#  10  cnt_membertype                   687224 non-null  object
#  11  cmp_campaigndonationreporting    687224 non-null  object
#  12  cmp_campaignentryreporting       687224 non-null  object
#  13  cmp_isemergency                  687224 non-null  boolean
#  14  cmp_isonline                     687224 non-null  object
#  15  cmp_objective                    687224 non-null  object
#  16  cmp_objectivepublic              687224 non-null  object
#  17  cmp_segment                      687224 non-null  object
#  18  cmp_status                       687224 non-null  object
#  19  rcd_isdeleted                    685181 non-null  boolean
#  20  rcd_annualizedquota              685181 non-null  float64
#  21  rcd_amount                       685181 non-null  float64
#  22  rcd_paidamount                   684329 non-null  float64
#  23  rcd_totalpaidinstallments        684329 non-null  float64
#  24  rcd_installmentperiod            687224 non-null  object
#  25  opp_type                         687224 non-null  object
# dtypes: boolean(5), float64(5), object(15), string(1)
# memory usage: 116.7+ MB

# %%
df_model_athena.shape
# Out:
# (687224, 26)

# %% [markdown]
# ## Transformaciones de datos

# %% [markdown]
# ### Paso 1
# - Recorremos el dataset, generando una columna por cada valor de los campos tipo lista, antes eliminamos de la lista valores vacios
# - Utilizamos la libreria MultiLabelBinarizer que por cada campo de tipo lista, devuelve una columna con valores 1, 0 en función de si está o no

# %%
df_model_athena.set_index('cnt_id');

# %%
df_model_athena_dummys = df_model_athena
def gene_list(x, column):
    list_dat = []
    for val in x:
        if val and val != '':
            list_dat.append(column + "_" + val)
    return list_dat
for col, typ in zip(df_model_athena_dummys.columns, df_model_athena_dummys.dtypes):
    if typ == 'object':
        df_model_athena_dummys[col] = df_model_athena_dummys[col].apply(gene_list, column=col)
        mlb = MultiLabelBinarizer()
        a = mlb.fit_transform(df_model_athena_dummys[col])
        df_expanded = pd.DataFrame(a, columns=mlb.classes_, index=df_model_athena_dummys.index)
        # merge them using the following:
        df_model_athena_dummys = df_model_athena_dummys.merge(df_expanded, left_index=True, right_index=True)

# %% [markdown]
# ### Paso 2
# Eliminamos las columnas de tipo lista

# %%
for col, typ in zip(df_model_athena_dummys.columns, df_model_athena_dummys.dtypes):
    if typ == 'object':
        df_model_athena_dummys = df_model_athena_dummys.drop([col],axis=1)

# %%
df_model_athena_dummys.shape
# Out:
# (687224, 171)

# %% [markdown]
# ### Paso 3
# - Buscamos outliers en los datos, es decir valores anómalos y los reemplazamos por los valores más altos o bajos

# %%
for col, typ in zip(df_model_athena_dummys.columns, df_model_athena_dummys.dtypes):
    if typ != "string" and typ != "int64" and typ != "boolean":
        upper_limit = df_model_athena_dummys[col].mean() + 3* df_model_athena_dummys[col].std() # Right from the mean
        lower_limit = df_model_athena_dummys[col].mean() - 3* df_model_athena_dummys[col].std() # Left from the mean
        df_model_athena_dummys[col].loc[(df_model_athena_dummys[col] > upper_limit)] = upper_limit
        df_model_athena_dummys[col].loc[(df_model_athena_dummys[col] < lower_limit)] = lower_limit
# Out:
# /tmp/ipykernel_880/2493348499.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model_athena_dummys[col].loc[(df_model_athena_dummys[col] > upper_limit)] = upper_limit
# /tmp/ipykernel_880/2493348499.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model_athena_dummys[col].loc[(df_model_athena_dummys[col] < lower_limit)] = lower_limit

# %%
pd.set_option('max_colwidth', -1)
pd.set_option('display.max_columns', None)
df_model_athena_dummys.sort_values(by="rcd_totalpaidinstallments", ascending=False).head(10)
# Out:
# /tmp/ipykernel_880/848794032.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)
#                     cnt_id  cnt_ltvscore  cnt_programaherencias  \
# 438116  0033Y00002uq4gYQAQ  7.0           False
# 227135  0033Y00002upzSvQAI  8.0           False
# 357445  0033Y00002upxI6QAI  7.0           False
# 497772  0033Y00002upGbGQAU  8.0           False
# 196104  0033Y00002unqEzQAI  7.0           False
# 421579  0033Y00002uofddQAA  6.0           False
# 559768  0033Y00002upmbWQAQ  9.0           False
# 28838   0033Y00002uoDQqQAM  7.0           False
# 118979  0033Y00002uqMXvQAM  2.0           False
# 573186  0033Y00002unGhRQAU  9.0           False
#
#         cnt_programais  cnt_legacyconfidentiality  cmp_isemergency  \
# 438116  False           False                      False
# 227135  False           False                      False
# 357445  False           False                      False
# 497772  False           False                      False
# 196104  False           False                      False
# 421579  False           False                      False
# 559768  False           False                      False
# 28838   False           False                      False
# 118979  False           False                      False
# 573186  False           False                      False
#
#         rcd_isdeleted  rcd_annualizedquota  rcd_amount  rcd_paidamount  \
# 438116  False          144.000000           12.000000   1449.210000
# 227135  False          120.000000           30.000000   3018.331933
# 357445  False          72.120000            10.000000   2443.960000
# 497772  False          144.240000           12.020000   3018.331933
# 196104  False          204.000000           17.000000   1159.000000
# 421579  False          120.000000           10.000000   670.000000
# 559768  False          1200.000000          100.000000  3018.331933
# 28838   False          120.000000           10.000000   1124.550000
# 118979  False          10.000000            10.000000   1257.970000
# 573186  False          1418.891296          216.990468  3018.331933
#
#         rcd_totalpaidinstallments  opp_rating_Caliente  opp_rating_Frio  \
# 438116  117.440047                 1                    0
# 227135  117.440047                 1                    0
# 357445  117.440047                 1                    0
# 497772  110.000000                 1                    0
# 196104  93.000000                  1                    0
# 421579  84.000000                  1                    0
# 559768  84.000000                  1                    0
# 28838   84.000000                  1                    0
# 118979  82.000000                  1                    0
# 573186  78.000000                  1                    0
#
#         opp_rating_Templado  opp_stagename_Cancelada  opp_stagename_Cobrada  \
# 438116  0                    0                        1
# 227135  0                    1                        1
# 357445  0                    0                        1
# 497772  0                    0                        1
# 196104  0                    0                        1
# 421579  0                    0                        1
# 559768  0                    0                        1
# 28838   0                    0                        1
# 118979  0                    1                        1
# 573186  0                    0                        1
#
#         opp_stagename_Devuelta  opp_stagename_Devuelta manual  \
# 438116  0                       0
# 227135  0                       0
# 357445  0                       0
# 497772  0                       0
# 196104  0                       0
# 421579  0                       0
# 559768  0                       0
# 28838   0                       0
# 118979  0                       0
# 573186  0                       0
#
#         opp_stagename_Impagada  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_Interesado proactivo (espontaneo)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_Interesado reactivo (prompted)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_Muy interesado  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_No insistir: Elaborando testamento  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_No interesado (no interes o error)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_Perdida Cambio testamento (vivo)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_Perdida Interesado (fallecido)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_Perdida Interesado (vivo)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_stagename_Puesta al cobro  opp_stagename_Testamento a favor  \
# 438116  1                              0
# 227135  1                              0
# 357445  1                              0
# 497772  1                              0
# 196104  1                              0
# 421579  1                              0
# 559768  1                              0
# 28838   1                              0
# 118979  0                              0
# 573186  1                              0
#
#         opp_program_Conversion prospectos  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Cultivacion socios MASS  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  1
# 421579  1
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Cultivacion socios MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Cultivacion/conversion Donantes MASS  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Cultivacion/conversion Donantes MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Empresas y Colectivos Estrategicas  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Empresas y Colectivos Mass  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Empresas y Colectivos Mid, Mid +  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Fundaciones Mass  opp_program_Fundaciones Mid, Mid +  \
# 438116  0                             0
# 227135  0                             0
# 357445  0                             0
# 497772  0                             0
# 196104  0                             0
# 421579  0                             0
# 559768  0                             0
# 28838   0                             0
# 118979  0                             0
# 573186  0                             0
#
#         opp_program_Instituciones Publicas Mass  opp_program_Major Donors  \
# 438116  0                                        0
# 227135  0                                        0
# 357445  0                                        0
# 497772  0                                        0
# 196104  0                                        0
# 421579  0                                        0
# 559768  0                                        0
# 28838   0                                        0
# 118979  0                                        0
# 573186  0                                        0
#
#         opp_program_Mid+ Donors  opp_program_Otros 121  \
# 438116  0                        0
# 227135  0                        0
# 357445  0                        0
# 497772  0                        0
# 196104  0                        0
# 421579  0                        0
# 559768  1                        0
# 28838   0                        0
# 118979  0                        0
# 573186  1                        0
#
#         opp_program_Otros 12Few+  opp_program_Otros programas transversales  \
# 438116  0                         1
# 227135  0                         1
# 357445  0                         1
# 497772  0                         1
# 196104  0                         0
# 421579  0                         0
# 559768  0                         0
# 28838   0                         1
# 118979  0                         1
# 573186  0                         0
#
#         opp_program_Potenciales a Major Donors  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Prospectos Empresas & Colectivos Mass  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Publicos Especiales  opp_program_Reactivacion bajas MASS  \
# 438116  0                                0
# 227135  0                                0
# 357445  0                                0
# 497772  0                                0
# 196104  0                                0
# 421579  0                                0
# 559768  0                                0
# 28838   0                                0
# 118979  0                                0
# 573186  0                                0
#
#         opp_program_Reactivacion bajas MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Reactivacion/conversion EXDonantes MASS  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Reactivacion/conversion EXDonantes MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         opp_program_Retencion 1r ano MASS  opp_program_Retencion 1r ano MID  \
# 438116  0                                  0
# 227135  0                                  0
# 357445  0                                  0
# 497772  0                                  0
# 196104  0                                  0
# 421579  0                                  0
# 559768  0                                  0
# 28838   0                                  0
# 118979  0                                  0
# 573186  0                                  0
#
#         opp_program_Testamentarios  opp_typefundraisingcontribution_A  \
# 438116  0                           1
# 227135  0                           1
# 357445  0                           1
# 497772  0                           1
# 196104  0                           0
# 421579  0                           0
# 559768  0                           1
# 28838   0                           1
# 118979  0                           1
# 573186  0                           0
#
#         opp_typefundraisingcontribution_H  opp_typefundraisingcontribution_S  \
# 438116  0                                  1
# 227135  0                                  1
# 357445  0                                  1
# 497772  0                                  1
# 196104  0                                  1
# 421579  0                                  1
# 559768  0                                  1
# 28838   0                                  1
# 118979  0                                  0
# 573186  0                                  1
#
#         cnt_program_Conversion prospectos  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Cultivacion socios MASS  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  1
# 421579  1
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Cultivacion socios MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Cultivacion/conversion Donantes MASS  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Cultivacion/conversion Donantes MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Empresas y Colectivos Estrategicas  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Empresas y Colectivos Mass  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Empresas y Colectivos Mid, Mid +  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Fundaciones Mass  cnt_program_Fundaciones Mid, Mid +  \
# 438116  0                             0
# 227135  0                             0
# 357445  0                             0
# 497772  0                             0
# 196104  0                             0
# 421579  0                             0
# 559768  0                             0
# 28838   0                             0
# 118979  0                             0
# 573186  0                             0
#
#         cnt_program_Instituciones Publicas Mass  cnt_program_Major Donors  \
# 438116  0                                        0
# 227135  0                                        0
# 357445  0                                        0
# 497772  0                                        0
# 196104  0                                        0
# 421579  0                                        0
# 559768  0                                        0
# 28838   0                                        0
# 118979  0                                        0
# 573186  0                                        0
#
#         cnt_program_Mid+ Donors  cnt_program_Otros 12Few+  \
# 438116  0                        0
# 227135  0                        0
# 357445  0                        0
# 497772  0                        0
# 196104  0                        0
# 421579  0                        0
# 559768  1                        0
# 28838   0                        0
# 118979  0                        0
# 573186  1                        0
#
#         cnt_program_Otros programas transversales  \
# 438116  1
# 227135  1
# 357445  1
# 497772  1
# 196104  0
# 421579  0
# 559768  0
# 28838   1
# 118979  0
# 573186  0
#
#         cnt_program_Potenciales a Major Donors  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Prospectos Empresas & Colectivos Mass  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Publicos Especiales  cnt_program_Reactivacion bajas MASS  \
# 438116  0                                0
# 227135  0                                0
# 357445  0                                0
# 497772  0                                0
# 196104  0                                0
# 421579  0                                0
# 559768  0                                0
# 28838   0                                0
# 118979  0                                0
# 573186  0                                0
#
#         cnt_program_Reactivacion bajas MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Reactivacion/conversion EXDonantes MASS  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  1
# 573186  0
#
#         cnt_program_Reactivacion/conversion EXDonantes MID  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Retencion 1r ano MASS  cnt_program_Retencion 1r ano MID  \
# 438116  0                                  0
# 227135  0                                  0
# 357445  0                                  0
# 497772  0                                  0
# 196104  0                                  0
# 421579  0                                  0
# 559768  0                                  0
# 28838   0                                  0
# 118979  0                                  0
# 573186  0                                  0
#
#         cnt_program_Testamentarios  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_program_Vehiculo donacion de Gran Donante = YES  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cnt_membertype_Baja  cnt_membertype_Baja + Donante  \
# 438116  0                    0
# 227135  0                    0
# 357445  0                    0
# 497772  0                    0
# 196104  0                    0
# 421579  0                    0
# 559768  0                    0
# 28838   0                    0
# 118979  0                    0
# 573186  0                    0
#
#         cnt_membertype_Baja + Exdonante  cnt_membertype_Donante  \
# 438116  0                                0
# 227135  1                                0
# 357445  0                                0
# 497772  0                                0
# 196104  0                                0
# 421579  0                                0
# 559768  0                                0
# 28838   0                                0
# 118979  0                                0
# 573186  0                                0
#
#         cnt_membertype_Exdonante  cnt_membertype_Nada  \
# 438116  0                         0
# 227135  0                         0
# 357445  0                         0
# 497772  0                         0
# 196104  0                         0
# 421579  0                         0
# 559768  0                         0
# 28838   0                         0
# 118979  1                         0
# 573186  0                         0
#
#         cnt_membertype_Nada (Donante SMS)  cnt_membertype_Socio  \
# 438116  0                                  0
# 227135  0                                  0
# 357445  0                                  0
# 497772  0                                  0
# 196104  0                                  1
# 421579  0                                  1
# 559768  0                                  0
# 28838   0                                  0
# 118979  0                                  0
# 573186  0                                  0
#
#         cnt_membertype_Socio + Donante  cnt_membertype_Socio + Exdonante  \
# 438116  1                               0
# 227135  0                               0
# 357445  0                               1
# 497772  0                               1
# 196104  0                               0
# 421579  0                               0
# 559768  0                               1
# 28838   0                               1
# 118979  0                               0
# 573186  0                               1
#
#         cmp_campaigndonationreporting_11-Tlmk captacion  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaigndonationreporting_12-Iniciativa Solidaria off line  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaigndonationreporting_13-Iniciativa Solidaria Online  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaigndonationreporting_14-Celebraciones  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaigndonationreporting_15-Television  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaigndonationreporting_16-Captacion off resto  \
# 438116  1
# 227135  1
# 357445  1
# 497772  1
# 196104  1
# 421579  1
# 559768  1
# 28838   1
# 118979  1
# 573186  0
#
#         cmp_campaigndonationreporting_21-Digital leads (email/tlmk)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaigndonationreporting_22-Digital Publi  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# ...
# 118979  0
# 573186  0
#
#         cmp_campaignentryreporting_34-Fide resto  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaignentryreporting_35-Tlmk reactivacion bajas  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaignentryreporting_36-Tlmk impagos  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_campaignentryreporting_41-Resto  cmp_isonline_NA  cmp_isonline_No  \
# 438116  0                                    0                1
# 227135  0                                    0                1
# 357445  0                                    0                1
# 497772  0                                    0                1
# 196104  0                                    0                1
# 421579  0                                    0                1
# 559768  0                                    0                1
# 28838   0                                    0                1
# 118979  0                                    0                1
# 573186  0                                    0                1
#
#         cmp_isonline_Si  cmp_objective_Captacion de leads  \
# 438116  0                0
# 227135  0                0
# 357445  0                0
# 497772  0                0
# 196104  0                0
# 421579  0                0
# 559768  0                0
# 28838   0                0
# 118979  0                0
# 573186  0                0
#
#         cmp_objective_Captacion de socios o donantes  \
# 438116  1
# 227135  1
# 357445  1
# 497772  1
# 196104  1
# 421579  1
# 559768  1
# 28838   1
# 118979  1
# 573186  0
#
#         cmp_objective_Conversion  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_objective_Conversion (de lead o donante a socio)  \
# 438116  0
# 227135  0
# 357445  0
# 497772  0
# 196104  0
# 421579  0
# 559768  0
# 28838   0
# 118979  0
# 573186  0
#
#         cmp_objective_Cultivacion  cmp_objective_Desconocido  \
# 438116  1                          1
# 227135  0                          1
# 357445  0                          1
# 497772  1                          1
# 196104  0                          0
# 421579  0                          0
# 559768  1                          1
# 28838   1                          1
# 118979  1                          0
# 573186  0                          1
#
#         cmp_objective_Informativo  cmp_objective_Otros  \
# 438116  0                          0
# 227135  0                          0
# 357445  0                          0
# 497772  0                          0
# 196104  0                          0
# 421579  0                          0
# 559768  0                          0
# 28838   0                          0
# 118979  0                          0
# 573186  0                          0
#
#         cmp_objective_Recuperacion  cmp_objective_Upgrade  \
# 438116  0                           0
# 227135  0                           0
# 357445  0                           0
# 497772  0                           0
# 196104  0                           0
# 421579  0                           0
# 559768  0                           0
# 28838   0                           0
# 118979  0                           0
# 573186  0                           1
#
#         cmp_objectivepublic_MASS  cmp_segment_Asociados  \
# 438116  0                         0
# 227135  0                         0
# 357445  0                         0
# 497772  0                         0
# 196104  0                         0
# 421579  0                         0
# 559768  0                         0
# 28838   0                         0
# 118979  0                         0
# 573186  0                         0
#
#         cmp_segment_Asociados Espana  cmp_segment_Celebraciones  \
# 438116  0                             0
# 227135  0                             0
# 357445  0                             0
# 497772  0                             0
# 196104  0                             0
# 421579  0                             0
# 559768  0                             0
# 28838   0                             0
# 118979  0                             0
# 573186  0                             0
#
#         cmp_segment_Desconocido  cmp_segment_Frio individuos  \
# 438116  1                        1
# 227135  0                        1
# 357445  1                        1
# 497772  1                        1
# 196104  0                        1
# 421579  0                        1
# 559768  0                        1
# 28838   1                        1
# 118979  0                        1
# 573186  1                        0
#
#         cmp_segment_Leads  cmp_segment_Mass donors  cmp_segment_Mid donors  \
# 438116  0                  1                        0
# 227135  0                  1                        0
# 357445  0                  0                        0
# 497772  0                  1                        0
# 196104  0                  0                        0
# 421579  0                  0                        0
# 559768  0                  1                        0
# 28838   0                  1                        0
# 118979  0                  1                        0
# 573186  0                  1                        0
#
#         cmp_segment_Mid+ donors  cmp_segment_One to One  \
# 438116  0                        0
# 227135  0                        0
# 357445  0                        0
# 497772  0                        0
# 196104  0                        0
# 421579  0                        0
# 559768  0                        0
# 28838   0                        0
# 118979  0                        0
# 573186  0                        0
#
#         cmp_segment_Organizaciones  cmp_segment_Otros  \
# 438116  0                           0
# 227135  0                           0
# 357445  0                           0
# 497772  0                           0
# 196104  0                           0
# 421579  0                           0
# 559768  0                           0
# 28838   0                           0
# 118979  0                           0
# 573186  0                           0
#
#         cmp_segment_Testamentarios  cmp_status_Completed  cmp_status_Created  \
# 438116  0                           1                     0
# 227135  0                           1                     0
# 357445  0                           1                     0
# 497772  0                           1                     0
# 196104  0                           1                     0
# 421579  0                           1                     0
# 559768  0                           1                     0
# 28838   0                           1                     0
# 118979  0                           1                     0
# 573186  0                           1                     0
#
#         cmp_status_In Progress  rcd_installmentperiod_Bimensual  \
# 438116  0                       0
# 227135  0                       0
# 357445  0                       0
# 497772  0                       0
# 196104  0                       0
# 421579  0                       0
# 559768  0                       0
# 28838   0                       0
# 118979  0                       0
# 573186  0                       0
#
#         rcd_installmentperiod_Monthly  rcd_installmentperiod_Quarterly  \
# 438116  1                              0
# 227135  0                              1
# 357445  1                              0
# 497772  1                              0
# 196104  1                              0
# 421579  1                              0
# 559768  1                              0
# 28838   1                              0
# 118979  0                              0
# 573186  1                              1
#
#         rcd_installmentperiod_Semestral  rcd_installmentperiod_Yearly  \
# 438116  0                                1
# 227135  0                                1
# 357445  0                                1
# 497772  0                                1
# 196104  0                                0
# 421579  0                                0
# 559768  0                                1
# 28838   0                                1
# 118979  0                                1
# 573186  0                                0
#
#         opp_type_Herencia  opp_type_Membership  opp_type_Pago de Herencia  \
# 438116  0                  1                    0
# 227135  0                  1                    0
# 357445  0                  1                    0
# 497772  0                  1                    0
# 196104  0                  0                    0
# 421579  0                  0                    0
# 559768  0                  1                    0
# 28838   0                  1                    0
# 118979  0                  1                    0
# 573186  0                  0                    0
#
#         opp_type_Recurrent Donation
# 438116  1
# 227135  1
# 357445  1
# 497772  1
# 196104  1
# 421579  1
# 559768  1
# 28838   1
# 118979  0
# 573186  1

# %% [markdown]
# ### Paso 4
# Comprobamos nulos y los eliminamos, poniendo a 0 ya que todo son importes o clase mayoritaria

# %%
list_null_columns = df_model_athena_dummys.columns[df_model_athena_dummys.isna().any()].tolist()
for null_col in list_null_columns:
    if df_model_athena_dummys[null_col].dtype == "boolean":
        df_model_athena_dummys[null_col].fillna(False,inplace=True)
    else:
        df_model_athena_dummys[null_col] = df_model_athena_dummys[null_col].apply(lambda x: 0 if np.isnan(x) else x)

# %%
df_model_athena_dummys.columns[df_model_athena_dummys.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# ## Analisis de datos
# Buscamos relaciones entre las variables

# %% [markdown]
# ### Paso 1
# Generamos matriz de correlaciones

# %%
correlation_matrix = df_model_athena_dummys.drop(["cnt_id"],axis=1).corr()

# %%
cor_pr_her = pd.DataFrame(correlation_matrix["cnt_programaherencias"])

# %%
cor_pr_her.sort_values(by="cnt_programaherencias", ascending=False)
# Out:
#                                              cnt_programaherencias
# cnt_programaherencias                        1.000000
# opp_type_Herencia                            0.839126
# opp_typefundraisingcontribution_H            0.839017
# cmp_campaigndonationreporting_36-Fide resto  0.517187
# cmp_campaignentryreporting_34-Fide resto     0.513012
# ...                                               ...
# rcd_installmentperiod_Monthly               -0.063267
# opp_stagename_Cobrada                       -0.063714
# opp_typefundraisingcontribution_S           -0.352938
# opp_type_Recurrent Donation                 -0.352938
# rcd_isdeleted                               NaN
#
# [170 rows x 1 columns]

# %% [markdown]
# ### Paso 2
# Nos quedamos con las relaciones con la columna programa herencias

# %%
df_agg_prog_her = df_model_athena_dummys.groupby("cnt_programaherencias").agg("sum").select_dtypes("int").T

# %%
df_agg_prog_her.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, cnt_programais to opp_type_Recurrent Donation
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   False   164 non-null    object
#  1   True    164 non-null    object
# dtypes: object(2)
# memory usage: 3.8+ KB

# %% [markdown]
# ### Paso 3
# Calculamos totales de las variables objetivo

# %%
dat = pd.DataFrame(df_model_athena_dummys.groupby("cnt_programaherencias").count()["cnt_id"]).T

# %% [markdown]
# ### Paso 4
# Cruzamos los datos de la matriz de correlaciones con las distribuciones de socios por variable

# %%
df_concat_prog_her = pd.concat([df_agg_prog_her, cor_pr_her], axis=1)

# %%
df_concat_prog_her = df_concat_prog_her.loc[df_concat_prog_her[False] != 0]

# %%
df_concat_prog_her["dist_col_False"] = df_concat_prog_her[False] / dat[False][0]
df_concat_prog_her["dist_col_True"] = df_concat_prog_her[True] / dat[True][0]
df_concat_prog_her["lift"] = ((df_concat_prog_her["dist_col_True"] - df_concat_prog_her["dist_col_False"]) / (df_concat_prog_her["dist_col_False"]))

# %% [markdown]
# ### Paso 5
# Analizamos diferentes distribuciones por variable

# %%
x_values = ("NO", "SI")
list_rows_bars = cor_pr_her.sort_values(by="cnt_programaherencias", ascending=False).sample(20).index
for row in list_rows_bars:
    try:
        df_rel = df_concat_prog_her[[0,1]].loc[row]
    except:
        pass
    p = plt.bar(x_values, df_rel)
    plt.title(f"Programa Herencia vs {row}", fontsize=18, fontweight='bold')
    plt.xlabel('programa herencia', fontsize=15,)
    plt.bar_label(p, label_type='edge')
    plt.ylabel('frequency', fontsize=15)
    plt.margins(y=0.1)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Paso 6
# Nos quedamos con las columnas que sigan la siguiente distribución:
# - No tener un lift mayor que 10 (es decir que haya 10 veces mas distribución de la variable objetivo tiene programa herencias)
# - No tener un lift inferior al 50% del caso opuesta (evitamos variables que no indiquen nada para la variable tiene programa herencias)

# %%
variables_salida = df_concat_prog_her.loc[(df_concat_prog_her["lift"]<1000) & (df_concat_prog_her["lift"]>-0.5)]

# %%
variables_salida_list = variables_salida.index.tolist() + ["cnt_id"] + ["cnt_programaherencias"]

# %%
len(variables_salida_list)
# Out:
# 97

# %% [markdown]
# ## Guardamos la salida en un fichero parquet

# %%
df_preprocessed = df_model_athena_dummys[variables_salida_list]

# %%
df_preprocessed.to_parquet("msf_df_preprocessed.parquet")
